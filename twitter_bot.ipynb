# %% [markdown]
# <a href="https://colab.research.google.com/github/ZenoVka-Vestraq/twitter_scrapping_crawler/blob/main/twitter_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install Dependencies

# %%
pip install tweepy
pip install configparser
pip install pandas

# %% [markdown]
# Import Dependencies

# %%
import tweepy as tp
import configparser as cp
import pandas as pd

# %% [markdown]
# Use the configparser.ConfigParser() class to read the values from the config.ini file.

# %%
config = configparser.ConfigParser()
config.read('config.ini')

# %%
api_key = config['twitter']['api_key']
api_secret = config['twitter']['api_secret']

access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']

# %% [markdown]
# Authenticate keys and secrets

# %%
auth = tp.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token,access_token_secret)

api = tp.API(auth)

# %% [markdown]
# Create dataframe to house data scraped

# %%
columns = ['Time', 'User', 'Tweet']
data = []
for tweet in public_tweets:
    data.append([tweet.created_at, tweet.user.screen_name, tweet.text])

user_tweets = pd.DataFrame(data, columns=columns)

# %% [markdown]
# Display the results in dataframe format

# %%
print(user_tweets)
