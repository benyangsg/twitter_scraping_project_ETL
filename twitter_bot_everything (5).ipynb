# %% [markdown]
# # Team Members (Blue Clues)
#
# - ### Ben Yang
# - ### Carol Wong
# - ### Kyle Lua
# - ### Michael Ho

# %% [markdown]
# # Project Summary

# %% [markdown]
# The **project objectives** can be summarised into the following:
#
# 1. Use Python's open source Tweepy package and libraries to access Twitter API.
# 2. Scrape for quoted tweets that correlate to Elon Musk's tweets on 'Twitter' and 'Free Speech' keywords.
# 3. Do data cleaning on crawled data.
# 4. Create Entity Relationship Diagram.
# 5. Design database schema and data structure in PostgresSQL.
# 6. Load data into database using SQL.
# 7. Do sentiment analysis on cleaned data.

# %% [markdown]
# ## Questions to be Answered:
#
# Based on **Elon Musk's** Tweets using the keywords **"Free Speech"** and **"Twitter"**:
#
# 1) Is there a positive correlation between the number of ‘Likes’ and the number of ‘Retweets’?
# 2) What are the sentiments towards Elon Musk’s tweets based on the Quoted Tweets?

# %% [markdown]
# # Workflow Diagram
#
# <div>
# <img src="images/workflow%20diagram.png" width="900" border=1px style="display: inline-block; text-align: left;"/>
# </div>

# %% [markdown]
# # Entity Relationship Diagram - Star Schema
#
# <div>
# <img src="images/ERD_twitter_bot.png" width="850" border=1px style="display: inline-block; text-align: center;"/>
# </div>

# %% [markdown]
# # Twitter API Application
#
# In order to use Twitter API, a Twitter developer account is required.  Apply for the **Essential** level first, then upgrade to **Elevated** level.
#
# The steps are as follows:
#
# Go to <https://developer.twitter.com> and sign in to your Twitter account. Navigate to **Products → Twitter API**.
#
#
# <div>
# <img src="images/twitter-api-sign-up.png" width="600"  border=1px style="display: inline-block; text-align: left;"/>
# </div>

# %% [markdown]
# Then, scroll down to the bottom of the page and click **Get Started**. <br><br>
#
# <div>
# <img src="images/twitter-api-get-started.png" width="700" border=1px style="display: inline-block; text-align: left;"/>
# </div>

# %% [markdown]
# Click **Apply for a developer account**.
#
# <div>
# <img src="images/developer-account.png" width="700" border=1px style="display: inline-block; text-align: left;"/>
# </div>

# %% [markdown]
# Note that you will need to have a verified telephone number associated to your account. If you haven't done it yet, you will see the relevant message - click the button **Add a valid phone number** and follow the instructions.  Click **Next**.
#
# <div>
# <img src="images/essential-access-questions.png" width="700" border=1px style="display: inline-block; text-align: left;"/>
# </div>

# %% [markdown]
# Fill in the data in the needed fields.  Click **Next**.
#
# <div>
# <img src="images/fill-in-the-required-fields.png" width="700" border=1px style="display: inline-block; text-align: left;"/>
# </div>

# %% [markdown]
# Accept the Developer agreement & policy.
#
# <div>
# <img src="images/developer-agreement-policy.png" width="700" border=1px style="display: inline-block; text-align: left;"/>
# </div>

# %% [markdown]
# Verify email. <br><br>
#
# <div>
# <img src="images/verify-email.png" width="600" border=1px style="display: inline-block; text-align: left;"/>
# </div>

# %% [markdown]
# After email verification, create a App. Give it a name and click **Get keys**. <br><br>
#
# <div>
# <img src="images/create-app-get-keys.png" width="600" border=1px style="display: inline-block; text-align: left;"/>
# </div>

# %% [markdown]
# # Upgrade to Elevated access

# %% [markdown]
# Here are the steps to apply for elevated access on the Twitter developer portal:
#
# Go back to the Developer Portal. Navigate to **Products → Twitter API v2 → Elevated**, then click **Apply for Elevated**. <br><br>
#
# <div>
# <img src="images/apply-elevated-access.png" width="600" border=1px style="display: inline-block; text-align: left;"/>
# </div>

# %% [markdown]
# On the next step, fill the fields with basic info and click **Next**.
#
# <div>
# <img src="images/basic-info.png" width="600" border=1px style="display: inline-block; text-align: left;"/>
# </div>

# %% [markdown]
# On the next page, you need to give detailed answers to the set of questions about how you are going to use Twitter API. When you finish, click the button **Next**.
#
# <div>
# <img src="images/intended-use.png" width="600" border=1px style="display: inline-block; text-align: left;"/>
# </div>

# %% [markdown]
# On the next page  Review you can check your data and answers. If everything is ok, click **Next**.
#
# <div>
# <img src="images/apply-elevated-review.png" width="600" border=1px style="display: inline-block; text-align: left;"/>
# </div>

# %% [markdown]
# Accept the Developer agreement & policy. Click **Submit**.
#
# <div>
# <img src="images/developer-agreement-policy.png" width="600" border=1px style="display: inline-block; text-align: left;"/>
# </div>

# %% [markdown]
# You will receive an email from Twitter once the Elevated access application has been approved.
#
# <div>
# <img src="images/developer-account-approved.png" width="600" border=1px style="display: inline-block; text-align: left;"/>
# </div>

# %% [markdown]
# Go back to Developer Portal and copy the keys and access tokens.<br><br>
#
# <div>
# <img src="images/keys-tokens.png" width="600" border=1px style="display: inline-block; text-align: left;"/>
# </div>

# %% [markdown]
# # DESIGN THINKING METHOLOGY
#
# - ### Define:
# Clearly define the project objectives and deliverables.
#
# - ### Ideate:
# Generate a wide range of ideas for the project. Out-of-the-box thinking during this stage.
#
# - ### Prototype:
# Create a baseline codes representation of one or more of the ideas generated during the ideation stage.  Repeat if needed.
#
# - ### Test:
# Gather feedbacks on the prototype to validate the design and identify areas for improvement.
#
# - ### Iterate:
# Use the findings gathered during testing phase to iterate on the design, repeating steps 3 & 4 as needed until an acceptable solution is found.

# %% [markdown]
# # Project Tools and Open Source Libraries
#
# - #### Project Management Tool/ Gantt Chart : Monday.com <br><br>
#
# <div>
# <img src="images/monday.png" width="800" border=1px style="display: inline-block; text-align: left;"/>
# </div>
#
# - #### Development/Documentation: Jupyter Notebook
#
# - #### Code Development: Python
#
# - #### Database: PostgreSQL
#
# - #### Twitter Scaping: Tweepy
#
# - #### Entity Relationship Diagram: LucidChart
#
# - #### Open-source libraries for ETL process:
#
# #### EXTRACT
# - tweepy for accessing the Twitter API
# - configparser for hiding keys and secrets
#
# #### TRANSFORM
# - pandas for data manipulation and analysis
# - pytz for accessing timezone
# - re for cleaning tweets
# - nltk for cleaning stopwords
# - matplotlib for creating visualisations
# - VADER for sentiment analysis
#
# #### LOAD
# - psycopg2 for data migration and manipulation from postgresql

# %% [markdown]
# # TWITTER API ON TWEEPY
#
# With **Tweepy.Cursor** class object, the amount of tweets scraped were limited (sometimes only able to get 10 tweets) as well as the extracted tweets text were truncated.  Thus they were insufficient and unsuitable for sentiment analysis use.
#
# However, with **Tweepy.Paginator** class object, it allows us to extract more tweets (up to 1000 tweets), access the quoted tweets entity that correlates to Elon Musk's tweets, and there were no truncation of tweets text.  The result provided us which a good sample size to do sentiment analysis.
#
# As seen in the example below, the Tweepy Paginator class object uses the bearer token authentication.
#
# <div>
# <img src="images/tweepy-client-authentication.png" width="700" border=1px style="display: inline-block; text-align: left;">
# </div>
#
# # Sample code for getting more than 100 tweets from the last 7 days
#
# <div>
# <img src="images/tweepy-paginator.png" width="600" border=1px style="display: inline-block; text-align: left;">
# </div>

# %% [markdown]
# Install Packages

# %%
# %pip install tweepy
# %pip install pandasy
# %pip install configparser
# %pip install psycopg2
# %pip install ipython-sql
# %pip install langdetect
# %pip install sqlalchemy
# %pip install vaderSentiment
# %pip install numpy
# %pip install matplotlib

# %% [markdown]
# Import Libraries

# %%
import tweepy
import configparser as cp
import pandas as pd
import pytz
import psycopg2
import re
import nltk
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords
from datetime import datetime

# %% [markdown]
# Read Configs (Without showing token keys in the python script)

# %%
config = cp.RawConfigParser()
config.read('config.ini')
bt = config['twitter']['bearer_token']

api_key = config['twitter']['api_key']
api_secret = config['twitter']['api_key_secret']

access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']

# %% [markdown]
# Authentication

# %%
auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token,access_token_secret)

api = tweepy.API(auth)

client = tweepy.Client(bearer_token=bt)

# %% [markdown]
# Define The User And Keywords To Search For

# %%
user = "ElonMusk"
keywords = ["Free Speech", "Twitter"]

# %% [markdown]
# Define The Date Range

# %%
utc = pytz.timezone('UTC')
start_date = datetime(2019, 1, 1, tzinfo=utc)
end_date = datetime.now(utc)

# %% [markdown]
# Create Dataframe to House Scraped Data for dim_target_user Table

# %%
columns = ['user_id', 'user_name', 'location', 'verified', 'followers_count']
data = []

# %% [markdown]
# Extract and Print User Profile

# %%
tweet = api.get_user(screen_name = user)
user_id = tweet.id
screen_name = tweet.screen_name
location = tweet.location
verified = tweet.verified
followers_count = tweet.followers_count
data.append([user_id,screen_name,location,verified,followers_count])
dim_target_user = pd.DataFrame(data, columns = columns)

# Print extracted user profile
print(dim_target_user)
# Out:
#     user_id user_name location  verified  followers_count
# 0  44196397  elonmusk               True        127753468

# %% [markdown]
# Connect to Postgres and Create Database tweetdb

# %%
config = cp.ConfigParser()
config.read('config.ini')

db_host = config["postgres"]["host"]
db_port = config["postgres"]["port"]
db_user = config["postgres"]["user"]
db_password = config["postgres"]["password"]
db_database = config["postgres"]["database"]

# Connect to the database
connection = psycopg2.connect(
    host = db_host, 
    port = db_port,
    user = db_user, 
    password = db_password, 
    database = db_database
)

connection.autocommit = True

# Name the database
db_name = "tweetdb"
 
# Creating a cursor object 
cursor = connection.cursor()

# Check if database already exists 
cursor.execute("SELECT 1 FROM pg_database WHERE datname = '" + db_name + "'")
exists = cursor.fetchone()
if not exists:
    cursor.execute("CREATE DATABASE " + db_name)
    connection.commit()
    print("Database has been created successfully !!")
else:
    print("Database already exists !!!")
# Out:
# Database has been created successfully !!

# %% [markdown]
# Create Table 'dim_target_user' in Postgres Database

# %%
# %reload_ext sql
connection = psycopg2.connect(
    host=db_host, 
    port=db_port,
    user=db_user, 
    password=db_password, 
    dbname=db_name
)

connection.autocommit = True
cursor = connection.cursor()
create_table ='''
CREATE TABLE dim_target_user (
user_id numeric PRIMARY KEY,
user_name text,
location text,
verified boolean,
followers_count numeric
);
'''

table_name = "dim_target_user"

cursor.execute(f"SELECT to_regclass('{table_name}');")

if cursor.fetchone()[0]:
    print(f"Table '{table_name}' already exists!")
else:
    cursor.execute(create_table)
    print(f"Successfully created {table_name} table!")
# Out:
# Successfully created dim_target_user table!

# %% [markdown]
# Commit Data Into Database and Close the Connection

# %%
cursor = connection.cursor()

for index, row in dim_target_user.iterrows():
    cursor.execute("INSERT INTO dim_target_user (user_id, user_name, location, verified, followers_count) VALUES (%s, %s, %s, %s, %s)", (row['user_id'], row['user_name'], row['location'], row['verified'], row['followers_count']))

# Commit Changes
connection.commit()
print("Successfully committed!")

# Close connection
cursor.close()
connection.close()
print("Connection closed!")
# Out:
# Successfully committed!
# Connection closed!

# %% [markdown]
# ==================================================================================================================

# %% [markdown]
# Create Dataframe to House Scraped Data for dim_tweets_w_keywords Table

# %%
keyword_1 = "Free Speech"
keyword_2  = "Twitter"
columns = ['date', 'tweet_id', 'tweet', 'source', 'user_name', 'user_id', 'keyword_1', 'keyword_2', 'total_likes', 'total_retweets']
data2 = []

# %% [markdown]
# Iterate Over Tweets and Print Those Containing The Keywords

# %%
for tweet in tweepy.Cursor(api.user_timeline, screen_name=user, tweet_mode='extended', exclude_replies=True, ).items():
    tweet_datetime = tweet.created_at.replace(tzinfo=utc)
    if tweet_datetime < end_date and tweet_datetime > start_date:
        kw1 = keyword_1.lower() in tweet.full_text.lower()
        kw2 = keyword_2.lower() in tweet.full_text.lower()
        if kw1 or kw2:
            data2.append([tweet_datetime, tweet.id, tweet.full_text, tweet.source, tweet.user.screen_name, tweet.user.id, kw1, kw2, tweet.favorite_count, tweet.retweet_count])

dim_tweets_w_keywords = pd.DataFrame(data2, columns=columns)

# Print tweet results with specified keywords
print(dim_tweets_w_keywords)
# Out:
#                          date             tweet_id  \
# 0   2023-01-27 04:19:47+00:00  1618826074724634625
# 1   2023-01-25 22:11:46+00:00  1618371072486936578
# 2   2023-01-21 17:41:22+00:00  1616853475220156417
# 3   2023-01-21 00:31:38+00:00  1616594332907372544
# 4   2023-01-21 00:18:21+00:00  1616590989145313283
# ..                        ...                  ...
# 131 2022-10-27 13:08:00+00:00  1585619322239561728
# 132 2022-10-26 18:45:58+00:00  1585341984679469056
# 133 2022-10-26 15:27:40+00:00  1585292083610279936
# 134 2022-10-12 21:09:41+00:00  1580304724082843648
# 135 2022-10-04 22:39:41+00:00  1577428272056389633
#
#                                                  tweet              source  \
# 0                   Twitter is the PvP of social media  Twitter for iPhone
# 1    Changed my name to Mr. Tweet, now Twitter won’...  Twitter for iPhone
# 2    Ads are too frequent on Twitter and too big. T...  Twitter for iPhone
# 3    Next Twitter update will remember whether you ...  Twitter for iPhone
# 4    In coming months, Twitter will translate &amp;...  Twitter for iPhone
# ..                                                 ...                 ...
# 131   Dear Twitter Advertisers https://t.co/GMwHmInPAS  Twitter for iPhone
# 132  Entering Twitter HQ – let that sink in! https:...  Twitter for iPhone
# 133  A beautiful thing about Twitter is how it empo...  Twitter for iPhone
# 134        Please buy my perfume, so I can buy Twitter  Twitter for iPhone
# 135  Buying Twitter is an accelerant to creating X,...  Twitter for iPhone
#
#     user_name   user_id  keyword_1  keyword_2  total_likes  total_retweets
# 0    elonmusk  44196397      False       True       273832           25881
# 1    elonmusk  44196397      False       True       915343           56927
# 2    elonmusk  44196397      False       True       258216           15629
# 3    elonmusk  44196397      False       True        76808            6791
# 4    elonmusk  44196397      False       True       294361           25602
# ..        ...       ...        ...        ...          ...             ...
# 131  elonmusk  44196397      False       True       737422          108730
# 132  elonmusk  44196397      False       True      1376727          180472
# 133  elonmusk  44196397      False       True       374600           45865
# 134  elonmusk  44196397      False       True       574986           41577
# 135  elonmusk  44196397      False       True       416846           35464
#
# [136 rows x 10 columns]

# %%
#dim_tweets_w_keywords = dim_tweets_w_keywords.reset_index(drop=True)
#display(dim_tweets_w_keywords)

# %% [markdown]
# Filter Away Retweets

# %%
dim_tweets_w_keywords.drop(dim_tweets_w_keywords[dim_tweets_w_keywords['tweet'].str.contains('RT')].index,inplace=True)
display(dim_tweets_w_keywords)
# Out:
#                          date             tweet_id  \
# 0   2023-01-27 04:19:47+00:00  1618826074724634625
# 1   2023-01-25 22:11:46+00:00  1618371072486936578
# 2   2023-01-21 17:41:22+00:00  1616853475220156417
# 3   2023-01-21 00:31:38+00:00  1616594332907372544
# 4   2023-01-21 00:18:21+00:00  1616590989145313283
# ..                        ...                  ...
# 131 2022-10-27 13:08:00+00:00  1585619322239561728
# 132 2022-10-26 18:45:58+00:00  1585341984679469056
# 133 2022-10-26 15:27:40+00:00  1585292083610279936
# 134 2022-10-12 21:09:41+00:00  1580304724082843648
# 135 2022-10-04 22:39:41+00:00  1577428272056389633
#
#                                                  tweet              source  \
# 0                   Twitter is the PvP of social media  Twitter for iPhone
# 1    Changed my name to Mr. Tweet, now Twitter won’...  Twitter for iPhone
# 2    Ads are too frequent on Twitter and too big. T...  Twitter for iPhone
# 3    Next Twitter update will remember whether you ...  Twitter for iPhone
# 4    In coming months, Twitter will translate &amp;...  Twitter for iPhone
# ..                                                 ...                 ...
# 131   Dear Twitter Advertisers https://t.co/GMwHmInPAS  Twitter for iPhone
# 132  Entering Twitter HQ – let that sink in! https:...  Twitter for iPhone
# 133  A beautiful thing about Twitter is how it empo...  Twitter for iPhone
# 134        Please buy my perfume, so I can buy Twitter  Twitter for iPhone
# 135  Buying Twitter is an accelerant to creating X,...  Twitter for iPhone
#
#     user_name   user_id  keyword_1  keyword_2  total_likes  total_retweets
# 0    elonmusk  44196397      False       True       273832           25881
# 1    elonmusk  44196397      False       True       915343           56927
# 2    elonmusk  44196397      False       True       258216           15629
# 3    elonmusk  44196397      False       True        76808            6791
# 4    elonmusk  44196397      False       True       294361           25602
# ..        ...       ...        ...        ...          ...             ...
# 131  elonmusk  44196397      False       True       737422          108730
# 132  elonmusk  44196397      False       True      1376727          180472
# 133  elonmusk  44196397      False       True       374600           45865
# 134  elonmusk  44196397      False       True       574986           41577
# 135  elonmusk  44196397      False       True       416846           35464
#
# [121 rows x 10 columns]

# %% [markdown]
# Connect To Database and Create Table

# %%
# %reload_ext sql
connection = psycopg2.connect(
    host=db_host,
    port = db_port,
    user = db_user,
    password = db_password,
    database= db_name)

connection.autocommit = True
cursor = connection.cursor()
create_table ='''
CREATE TABLE dim_tweets_w_keywords (
date date,
tweet_id numeric PRIMARY KEY,
tweet varchar,
source varchar,
user_name varchar,
user_id numeric,
keyword_1 boolean,
keyword_2 boolean,
total_likes int,
total_retweets int
);
'''
table_name = "dim_tweets_w_keywords"

cursor.execute(f"SELECT to_regclass('{table_name}');")

if cursor.fetchone()[0]:
    print(f"Table '{table_name}' already exists!")
else:
    cursor.execute(create_table)
    print(f"Successfully created {table_name} table!")
# Out:
# Successfully created dim_tweets_w_keywords table!

# %% [markdown]
# Insert DataFrame Into Table In Database

# %%
# Connect to the database
connection = psycopg2.connect(
    host=db_host,
    port = db_port,
    user = db_user,
    password = db_password,
    database= db_name)

cursor = connection.cursor()

for index, row in dim_tweets_w_keywords.iterrows():
    cursor.execute("INSERT INTO dim_tweets_w_keywords (date, tweet_id, tweet, source, user_name, user_id, keyword_1, keyword_2, total_likes, total_retweets) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)", (row['date'], row['tweet_id'], row['tweet'], row['source'], row['user_name'], row['user_id'], row['keyword_1'], row['keyword_2'], row['total_likes'], row['total_retweets']))

#Commit Changes
connection.commit()

# %% [markdown]
# Close Connection

# %%
# Close the connection
cursor.close()
connection.close()

# %% [markdown]
# ==================================================================================================================

# %% [markdown]
# Create Scatterplot to Show Correlation Between Number of Likes and Number of Retweets (Using Dataframe)

# %%
import numpy as np

plt.scatter(dim_tweets_w_keywords.total_likes/1000, dim_tweets_w_keywords.total_retweets/1000)

plt.xlabel('Number of Likes (in thousands)')
plt.ylabel('Number of Retweets (in thousands)')
plt.title('Correlation Between Number of Likes & Number of Retweets')

# Add linear line of best fit
plt.plot(np.unique(dim_tweets_w_keywords.total_likes/1000), np.poly1d(np.polyfit(dim_tweets_w_keywords.total_likes/1000, dim_tweets_w_keywords.total_retweets/1000, 1))(np.unique(dim_tweets_w_keywords.total_likes/1000)))

#plt.savefig(r"C:\Users\Exclusive Auto\BIDA\Interim Project Final\correlation.png")
plt.show()

# %% [markdown]
# ==================================================================================================================

# %% [markdown]
# Create Empty DataFrame and Limit Sample Size to 20 Tweet IDs

# %%
sample = []

# Print the list
for index,row in dim_tweets_w_keywords.iloc[:20].iterrows():
    sample.append(row['tweet_id'])
    
display(sample)
# Out:
# [1618826074724634625,
#  1618371072486936578,
#  1616853475220156417,
#  1616594332907372544,
#  1616590989145313283,
#  1616533691156819968,
#  1616531077790826497,
#  1616524886201225217,
#  1616179085507702785,
#  1615398789585731587,
#  1614761844010528770,
#  1613995936585519104,
#  1610374789759205380,
#  1609109899233071104,
#  1608922473839620096,
#  1608663342956302337,
#  1608324539779551232,
#  1608175680407191552,
#  1607416119496945665,
#  1606396336592498688]

# %% [markdown]
# For Every Tweet ID, Retrieve 25 Quote Tweet IDs And Their Content

# %%
data = []
cols = ['tweet_id','quoted_tweet_id','content']

for i in sample:
    for tweet in tweepy.Paginator(client.get_quote_tweets, id = i,
                              max_results=25, exclude='retweets').flatten(limit=25):
        data.append([i,tweet.id, tweet.text])
    tweet_details = pd.DataFrame(data, columns=cols)
display(tweet_details)
# Out:
#                 tweet_id      quoted_tweet_id  \
# 0    1618826074724634625  1619976020916072448
# 1    1618826074724634625  1619955943592300544
# 2    1618826074724634625  1619940663881252864
# 3    1618826074724634625  1619910730844864513
# 4    1618826074724634625  1619908816442884097
# ..                   ...                  ...
# 495  1606396336592498688  1607872272232058881
# 496  1606396336592498688  1607863591293558785
# 497  1606396336592498688  1607844739726086144
# 498  1606396336592498688  1607812840945246208
# 499  1606396336592498688  1607796965890457600
#
#                                                content
# 0                 it’s so true https://t.co/hyQZOFJB2g
# 1    I'd like to believe so. I had my account on ho...
# 2    this mf hacked elons account and tweeted this ...
# 3                   fatos musk https://t.co/2cSRgkvCxl
# 4    ツイッターはソーシャルメディアの対人通信対戦zoy https://t.co/XCsPLIjwyp
# ..                                                 ...
# 495                          👌 https://t.co/rj1obw9X0a
# 496                 хаха блчть https://t.co/V5lG12zLUv
# 497  Hahahaha 🙄 what an idiot - but great job destr...
# 498  You know what, I am a bird and I'm not registe...
# 499                    Yesssss https://t.co/KwD03VTY4j
#
# [500 rows x 3 columns]

# %% [markdown]
# Check if The Quote Tweet ID Is Valid and Retrieve The Tweet ID

# %%
#insert a quoted_tweet_id from above and run. result will display its relevant tweet_id on the left.
status = api.get_status(1619940663881252864, tweet_mode='extended')
if hasattr(status,'quoted_status'):
    quoted_tweet_id = status.quoted_status.id
    print(f"Stems from tweet ID: {quoted_tweet_id}")
# Out:
# Stems from tweet ID: 1618826074724634625

# %% [markdown]
# Clean Tweets

# %%
def cleanTweets(tweet):
    tweet = re.sub('RT', '', tweet)
    tweet = re.sub('@[\S]*', ' ', tweet) #Remove mentions
    tweet = re.sub(r'https\S+', '', tweet) #Remove hyperlinks2
    tweet = re.sub(r'https?\/\/\S+', '', tweet) #Remove hyperlinks
    tweet = re.sub(r'&amp',' ', tweet) #Remove &amp
    tweet = re.sub('#[A-Za-z0-9]+', ' ', tweet) #Remove special characters
    tweet = re.sub(r'[^\x00-\x7F]+',' ', tweet) #Remove non-English words
    tweet = re.sub(r"(.)\1{2,}", r"\1", tweet) #Remove 3 repeating characters
    tweet = re.sub('[^\w\s]+',' ', tweet) #Remove punctuation
    tweet = re.sub('\n', '', tweet) #Remove newlines
    tweet = re.sub(' +', ' ', tweet) #Remove whitespaces
    tweet = re.sub('^[\s]+|[\s]+$', '', tweet) #Remove whitespaces
    tweet = tweet.lower() # make all lower case   
    return tweet

tweet_details['cleaned'] = tweet_details['content'].apply(cleanTweets)
display(tweet_details)
# Out:
#                 tweet_id      quoted_tweet_id  \
# 0    1618826074724634625  1619976020916072448
# 1    1618826074724634625  1619955943592300544
# 2    1618826074724634625  1619940663881252864
# 3    1618826074724634625  1619910730844864513
# 4    1618826074724634625  1619908816442884097
# ..                   ...                  ...
# 495  1606396336592498688  1607872272232058881
# 496  1606396336592498688  1607863591293558785
# 497  1606396336592498688  1607844739726086144
# 498  1606396336592498688  1607812840945246208
# 499  1606396336592498688  1607796965890457600
#
#                                                content  \
# 0                 it’s so true https://t.co/hyQZOFJB2g
# 1    I'd like to believe so. I had my account on ho...
# 2    this mf hacked elons account and tweeted this ...
# 3                   fatos musk https://t.co/2cSRgkvCxl
# 4    ツイッターはソーシャルメディアの対人通信対戦zoy https://t.co/XCsPLIjwyp
# ..                                                 ...
# 495                          👌 https://t.co/rj1obw9X0a
# 496                 хаха блчть https://t.co/V5lG12zLUv
# 497  Hahahaha 🙄 what an idiot - but great job destr...
# 498  You know what, I am a bird and I'm not registe...
# 499                    Yesssss https://t.co/KwD03VTY4j
#
#                                                cleaned
# 0                                         it s so true
# 1    i d like to believe so i had my account on hol...
# 2        this mf hacked elons account and tweeted this
# 3                                           fatos musk
# 4                                                  zoy
# ..                                                 ...
# 495
# 496
# 497  hahahaha what an idiot but great job destroyin...
# 498  you know what i am a bird and i m not register...
# 499                                                yes
#
# [500 rows x 4 columns]

# %% [markdown]
# To check if Tweets are in English, and Delete Non-English Tweets

# %%
from langdetect import detect

def is_english(text):
    try:
        return detect(text) == 'en'
    except:
        return False
    
tweet_details['is_english'] = tweet_details['cleaned'].apply(is_english)
tweet_details.drop(tweet_details[tweet_details['is_english'] == False].index, inplace=True)

display(tweet_details)
# Out:
#                 tweet_id      quoted_tweet_id  \
# 0    1618826074724634625  1619976020916072448
# 1    1618826074724634625  1619955943592300544
# 2    1618826074724634625  1619940663881252864
# 7    1618826074724634625  1619844454999007232
# 8    1618826074724634625  1619819859558408193
# ..                   ...                  ...
# 490  1606396336592498688  1608043012415799296
# 493  1606396336592498688  1608016755427004417
# 494  1606396336592498688  1607898321892552705
# 497  1606396336592498688  1607844739726086144
# 498  1606396336592498688  1607812840945246208
#
#                                                content  \
# 0                 it’s so true https://t.co/hyQZOFJB2g
# 1    I'd like to believe so. I had my account on ho...
# 2    this mf hacked elons account and tweeted this ...
# 7              so funny of him https://t.co/o9zlf8xUXB
# 8             You mean the HPV https://t.co/A92EKzputP
# ..                                                 ...
# 490         Vote for the right https://t.co/BVWPyhCtZM
# 493      https://t.co/VcAwKJmjW9\n\nNah he's hilarious
# 494  First time in a long time.... https://t.co/RjS...
# 497  Hahahaha 🙄 what an idiot - but great job destr...
# 498  You know what, I am a bird and I'm not registe...
#
#                                                cleaned  is_english
# 0                                         it s so true        True
# 1    i d like to believe so i had my account on hol...        True
# 2        this mf hacked elons account and tweeted this        True
# 7                                      so funny of him        True
# 8                                     you mean the hpv        True
# ..                                                 ...         ...
# 490                                 vote for the right        True
# 493                                 nah he s hilarious        True
# 494                          first time in a long time        True
# 497  hahahaha what an idiot but great job destroyin...        True
# 498  you know what i am a bird and i m not register...        True
#
# [290 rows x 5 columns]

# %% [markdown]
# Remove is_english Column

# %%
tweet_details.pop("is_english")

display(tweet_details)
# Out:
#                 tweet_id      quoted_tweet_id  \
# 0    1618826074724634625  1619976020916072448
# 1    1618826074724634625  1619955943592300544
# 2    1618826074724634625  1619940663881252864
# 7    1618826074724634625  1619844454999007232
# 8    1618826074724634625  1619819859558408193
# ..                   ...                  ...
# 490  1606396336592498688  1608043012415799296
# 493  1606396336592498688  1608016755427004417
# 494  1606396336592498688  1607898321892552705
# 497  1606396336592498688  1607844739726086144
# 498  1606396336592498688  1607812840945246208
#
#                                                content  \
# 0                 it’s so true https://t.co/hyQZOFJB2g
# 1    I'd like to believe so. I had my account on ho...
# 2    this mf hacked elons account and tweeted this ...
# 7              so funny of him https://t.co/o9zlf8xUXB
# 8             You mean the HPV https://t.co/A92EKzputP
# ..                                                 ...
# 490         Vote for the right https://t.co/BVWPyhCtZM
# 493      https://t.co/VcAwKJmjW9\n\nNah he's hilarious
# 494  First time in a long time.... https://t.co/RjS...
# 497  Hahahaha 🙄 what an idiot - but great job destr...
# 498  You know what, I am a bird and I'm not registe...
#
#                                                cleaned
# 0                                         it s so true
# 1    i d like to believe so i had my account on hol...
# 2        this mf hacked elons account and tweeted this
# 7                                      so funny of him
# 8                                     you mean the hpv
# ..                                                 ...
# 490                                 vote for the right
# 493                                 nah he s hilarious
# 494                          first time in a long time
# 497  hahahaha what an idiot but great job destroyin...
# 498  you know what i am a bird and i m not register...
#
# [290 rows x 4 columns]

# %% [markdown]
# To Remove Stopwords From Tweets

# %%
nltk.download('stopwords')

stopwords_list = set(stopwords.words('english'))
tweet_details['cleaned'] = tweet_details['cleaned'].apply(lambda x: ' '.join([word for word in x.split() if word.lower() not in stopwords_list]))

display(tweet_details)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kylel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                 tweet_id      quoted_tweet_id  \
# 0    1618826074724634625  1619976020916072448
# 1    1618826074724634625  1619955943592300544
# 2    1618826074724634625  1619940663881252864
# 7    1618826074724634625  1619844454999007232
# 8    1618826074724634625  1619819859558408193
# ..                   ...                  ...
# 490  1606396336592498688  1608043012415799296
# 493  1606396336592498688  1608016755427004417
# 494  1606396336592498688  1607898321892552705
# 497  1606396336592498688  1607844739726086144
# 498  1606396336592498688  1607812840945246208
#
#                                                content  \
# 0                 it’s so true https://t.co/hyQZOFJB2g
# 1    I'd like to believe so. I had my account on ho...
# 2    this mf hacked elons account and tweeted this ...
# 7              so funny of him https://t.co/o9zlf8xUXB
# 8             You mean the HPV https://t.co/A92EKzputP
# ..                                                 ...
# 490         Vote for the right https://t.co/BVWPyhCtZM
# 493      https://t.co/VcAwKJmjW9\n\nNah he's hilarious
# 494  First time in a long time.... https://t.co/RjS...
# 497  Hahahaha 🙄 what an idiot - but great job destr...
# 498  You know what, I am a bird and I'm not registe...
#
#                                                cleaned
# 0                                                 true
# 1    like believe account hold since december 19th ...
# 2                      mf hacked elons account tweeted
# 7                                                funny
# 8                                             mean hpv
# ..                                                 ...
# 490                                         vote right
# 493                                      nah hilarious
# 494                               first time long time
# 497  hahahaha idiot great job destroying billions m...
# 498  know bird registered right county even vote ev...
#
# [290 rows x 4 columns]

# %% [markdown]
# Drop Duplicates Inplace

# %%
cleaned_tw_list = tweet_details.drop_duplicates(subset=['cleaned'])
print('Result DataFrame:\n', cleaned_tw_list)
cleaned_tw_list = cleaned_tw_list.dropna(subset=['cleaned'])
display(cleaned_tw_list)
cleaned_tw_list.shape
# cleaned_tw_list.to_csv(fr"C:\Users\kylel\OneDrive\Desktop\BIDA\00 Interim Project\Project Files\cleaned_tw_list.csv", index=True)
# Out:
# Result DataFrame:
#                  tweet_id      quoted_tweet_id  \
# 0    1618826074724634625  1619976020916072448
# 1    1618826074724634625  1619955943592300544
# 2    1618826074724634625  1619940663881252864
# 7    1618826074724634625  1619844454999007232
# 8    1618826074724634625  1619819859558408193
# ..                   ...                  ...
# 490  1606396336592498688  1608043012415799296
# 493  1606396336592498688  1608016755427004417
# 494  1606396336592498688  1607898321892552705
# 497  1606396336592498688  1607844739726086144
# 498  1606396336592498688  1607812840945246208
#
#                                                content  \
# 0                 it’s so true https://t.co/hyQZOFJB2g
# 1    I'd like to believe so. I had my account on ho...
# 2    this mf hacked elons account and tweeted this ...
# 7              so funny of him https://t.co/o9zlf8xUXB
# 8             You mean the HPV https://t.co/A92EKzputP
# ..                                                 ...
# 490         Vote for the right https://t.co/BVWPyhCtZM
# 493      https://t.co/VcAwKJmjW9\n\nNah he's hilarious
# 494  First time in a long time.... https://t.co/RjS...
# 497  Hahahaha 🙄 what an idiot - but great job destr...
# 498  You know what, I am a bird and I'm not registe...
#
#                                                cleaned
# 0                                                 true
# 1    like believe account hold since december 19th ...
# 2                      mf hacked elons account tweeted
# 7                                                funny
# 8                                             mean hpv
# ..                                                 ...
# 490                                         vote right
# 493                                      nah hilarious
# 494                               first time long time
# 497  hahahaha idiot great job destroying billions m...
# 498  know bird registered right county even vote ev...
#
# [265 rows x 4 columns]
#                 tweet_id      quoted_tweet_id  \
# 0    1618826074724634625  1619976020916072448
# 1    1618826074724634625  1619955943592300544
# 2    1618826074724634625  1619940663881252864
# 7    1618826074724634625  1619844454999007232
# 8    1618826074724634625  1619819859558408193
# ..                   ...                  ...
# 490  1606396336592498688  1608043012415799296
# 493  1606396336592498688  1608016755427004417
# 494  1606396336592498688  1607898321892552705
# 497  1606396336592498688  1607844739726086144
# 498  1606396336592498688  1607812840945246208
#
#                                                content  \
# 0                 it’s so true https://t.co/hyQZOFJB2g
# 1    I'd like to believe so. I had my account on ho...
# 2    this mf hacked elons account and tweeted this ...
# 7              so funny of him https://t.co/o9zlf8xUXB
# 8             You mean the HPV https://t.co/A92EKzputP
# ..                                                 ...
# 490         Vote for the right https://t.co/BVWPyhCtZM
# 493      https://t.co/VcAwKJmjW9\n\nNah he's hilarious
# 494  First time in a long time.... https://t.co/RjS...
# 497  Hahahaha 🙄 what an idiot - but great job destr...
# 498  You know what, I am a bird and I'm not registe...
#
#                                                cleaned
# 0                                                 true
# 1    like believe account hold since december 19th ...
# 2                      mf hacked elons account tweeted
# 7                                                funny
# 8                                             mean hpv
# ..                                                 ...
# 490                                         vote right
# 493                                      nah hilarious
# 494                               first time long time
# 497  hahahaha idiot great job destroying billions m...
# 498  know bird registered right county even vote ev...
#
# [265 rows x 4 columns]
# (265, 4)

# %% [markdown]
# Connect to Database And Create Table

# %%
# %reload_ext sql
# Connect to the database
connection = psycopg2.connect(
    host=db_host,
    port = db_port,
    user = db_user,
    password = db_password,
    database= db_name)

connection.autocommit = True
cursor = connection.cursor()
create_table ='''
CREATE TABLE cleaned_twt_list (
tweet_id numeric,
quoted_tweet_id numeric,
content text,
cleaned text
);
'''
table_name = "cleaned_twt_list"

cursor.execute(f"SELECT to_regclass('{table_name}');")

if cursor.fetchone()[0]:
    print(f"Table '{table_name}' already exists!")
else:
    cursor.execute(create_table)
    print(f"Successfully created {table_name} table!")
# Out:
# Successfully created cleaned_twt_list table!

# %% [markdown]
# Insert DataFrame Into Created Table In PostGres

# %%
# Connect to the database
connection = psycopg2.connect(
    host=db_host,
    port = db_port,
    user = db_user,
    password = db_password,
    database= db_name)

cursor = connection.cursor()

for index, row in cleaned_tw_list.iterrows():
    cursor.execute("INSERT INTO cleaned_twt_list (tweet_id, quoted_tweet_id, content, cleaned) VALUES (%s, %s, %s, %s)", (row['tweet_id'], row['quoted_tweet_id'], row['content'], row['cleaned']))


#Commit Changes
connection.commit()

# %% [markdown]
# Close Connection

# %%
cursor.close()
connection.close()

# %% [markdown]
# ==================================================================================================================

# %% [markdown]
# Generate Wordcloud

# %%
# Read in your dataframe
#df = pd.read_csv('cleaned_tw_list.csv')

# Convert the relevant column of the dataframe into a string of text
text = ' '.join(cleaned_tw_list['cleaned'].tolist())

# Generate the word cloud
wordcloud = WordCloud().generate(text)

# Display the word cloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ==================================================================================================================

# %% [markdown]
# Analyse Sentiments Based on Quote Tweets

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()
cleaned_tw_list['compound'] = [analyzer.polarity_scores(x)['compound'] for x in cleaned_tw_list['cleaned']]
cleaned_tw_list['neg'] = [analyzer.polarity_scores(x)['neg'] for x in cleaned_tw_list['cleaned']]
cleaned_tw_list['neu'] = [analyzer.polarity_scores(x)['neu'] for x in cleaned_tw_list['cleaned']]
cleaned_tw_list['pos'] = [analyzer.polarity_scores(x)['pos'] for x in cleaned_tw_list['cleaned']]

display(cleaned_tw_list)
# Out:
#                 tweet_id      quoted_tweet_id  \
# 0    1618826074724634625  1619976020916072448
# 1    1618826074724634625  1619955943592300544
# 2    1618826074724634625  1619940663881252864
# 7    1618826074724634625  1619844454999007232
# 8    1618826074724634625  1619819859558408193
# ..                   ...                  ...
# 490  1606396336592498688  1608043012415799296
# 493  1606396336592498688  1608016755427004417
# 494  1606396336592498688  1607898321892552705
# 497  1606396336592498688  1607844739726086144
# 498  1606396336592498688  1607812840945246208
#
#                                                content  \
# 0                 it’s so true https://t.co/hyQZOFJB2g
# 1    I'd like to believe so. I had my account on ho...
# 2    this mf hacked elons account and tweeted this ...
# 7              so funny of him https://t.co/o9zlf8xUXB
# 8             You mean the HPV https://t.co/A92EKzputP
# ..                                                 ...
# 490         Vote for the right https://t.co/BVWPyhCtZM
# 493      https://t.co/VcAwKJmjW9\n\nNah he's hilarious
# 494  First time in a long time.... https://t.co/RjS...
# 497  Hahahaha 🙄 what an idiot - but great job destr...
# 498  You know what, I am a bird and I'm not registe...
#
#                                                cleaned  compound    neg  \
# 0                                                 true    0.4215  0.000
# 1    like believe account hold since december 19th ...    0.7579  0.000
# 2                      mf hacked elons account tweeted   -0.4019  0.403
# 7                                                funny    0.4404  0.000
# 8                                             mean hpv    0.0000  0.000
# ..                                                 ...       ...    ...
# 490                                         vote right    0.0000  0.000
# 493                                      nah hilarious    0.3182  0.341
# 494                               first time long time    0.0000  0.000
# 497  hahahaha idiot great job destroying billions m...   -0.1027  0.397
# 498  know bird registered right county even vote ev...    0.3612  0.000
#
#        neu    pos
# 0    0.000  1.000
# 1    0.754  0.246
# 2    0.597  0.000
# 7    0.000  1.000
# 8    1.000  0.000
# ..     ...    ...
# 490  1.000  0.000
# 493  0.000  0.659
# 494  1.000  0.000
# 497  0.230  0.374
# 498  0.902  0.098
#
# [265 rows x 8 columns]

# %% [markdown]
# DETERMINE THRESHOLD
#
# positive sentiment : (compound score >= 0.05)
#
# neutral sentiment : (compound score > -0.05) and (compound score < 0.05)
#
# negative sentiment : (compound score <= -0.05)

# %%
cleaned_tw_list['sentiment'] = ['positive' if x >= 0.05 else 'neutral' if x > -0.05 and x < 0.05 else 'negative' for x in cleaned_tw_list['compound']]

display(cleaned_tw_list)
# Out:
#                 tweet_id      quoted_tweet_id  \
# 0    1618826074724634625  1619976020916072448
# 1    1618826074724634625  1619955943592300544
# 2    1618826074724634625  1619940663881252864
# 7    1618826074724634625  1619844454999007232
# 8    1618826074724634625  1619819859558408193
# ..                   ...                  ...
# 490  1606396336592498688  1608043012415799296
# 493  1606396336592498688  1608016755427004417
# 494  1606396336592498688  1607898321892552705
# 497  1606396336592498688  1607844739726086144
# 498  1606396336592498688  1607812840945246208
#
#                                                content  \
# 0                 it’s so true https://t.co/hyQZOFJB2g
# 1    I'd like to believe so. I had my account on ho...
# 2    this mf hacked elons account and tweeted this ...
# 7              so funny of him https://t.co/o9zlf8xUXB
# 8             You mean the HPV https://t.co/A92EKzputP
# ..                                                 ...
# 490         Vote for the right https://t.co/BVWPyhCtZM
# 493      https://t.co/VcAwKJmjW9\n\nNah he's hilarious
# 494  First time in a long time.... https://t.co/RjS...
# 497  Hahahaha 🙄 what an idiot - but great job destr...
# 498  You know what, I am a bird and I'm not registe...
#
#                                                cleaned  compound    neg  \
# 0                                                 true    0.4215  0.000
# 1    like believe account hold since december 19th ...    0.7579  0.000
# 2                      mf hacked elons account tweeted   -0.4019  0.403
# 7                                                funny    0.4404  0.000
# 8                                             mean hpv    0.0000  0.000
# ..                                                 ...       ...    ...
# 490                                         vote right    0.0000  0.000
# 493                                      nah hilarious    0.3182  0.341
# 494                               first time long time    0.0000  0.000
# 497  hahahaha idiot great job destroying billions m...   -0.1027  0.397
# 498  know bird registered right county even vote ev...    0.3612  0.000
#
#        neu    pos sentiment
# 0    0.000  1.000  positive
# 1    0.754  0.246  positive
# 2    0.597  0.000  negative
# 7    0.000  1.000  positive
# 8    1.000  0.000   neutral
# ..     ...    ...       ...
# 490  1.000  0.000   neutral
# 493  0.000  0.659  positive
# 494  1.000  0.000   neutral
# 497  0.230  0.374  negative
# 498  0.902  0.098  positive
#
# [265 rows x 9 columns]

# %% [markdown]
# Create Table for 'dim_sentiments'

# %%
# %reload_ext sql
# Connect to the database
connection = psycopg2.connect(
    host=db_host,
    port = db_port,
    user = db_user,
    password = db_password,
    database= db_name)

connection.autocommit = True
cursor = connection.cursor()
create_table ='''
CREATE TABLE dim_sentiments (
sentiment_id serial PRIMARY KEY,
tweet_id numeric,
quoted_tweet_id numeric,
cleaned text,
neg numeric,
neu numeric,
pos numeric,
compound double precision,
sentiment text

);
'''
table_name = "dim_sentiments"

cursor.execute(f"SELECT to_regclass('{table_name}');")

if cursor.fetchone()[0]:
    print(f"Table '{table_name}' already exists!")
else:
    cursor.execute(create_table)
    print(f"Successfully created {table_name} table!")
# Out:
# Successfully created dim_sentiments table!

# %% [markdown]
# Commit Table Information

# %%
dim_sentiments = pd.DataFrame(cleaned_tw_list)
cursor = connection.cursor()

for index, row in dim_sentiments.iterrows():
    cursor.execute("INSERT INTO dim_sentiments (tweet_id, quoted_tweet_id, cleaned, neg, neu, pos, compound, sentiment) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)", (row['tweet_id'], row['quoted_tweet_id'], row['cleaned'], row['neg'], row['neu'], row['pos'], row['compound'], row['sentiment']))

#Commit Changes
connection.commit()

# %% [markdown]
# Close Connection

# %%
cursor.close()
connection.close()

# %% [markdown]
# ==================================================================================================================

# %% [markdown]
# Count Values for Sentiment Features and See Total — Percentage.

# %%
# Count the number of neutral, positive and negative sentiments
sentiment_count = cleaned_tw_list['sentiment'].value_counts()

# Create a new dataframe to store the results
result_df = pd.DataFrame(columns=['Sentiment', 'Total', 'Percentage'])

# Loop through the sentiment_count to add the values to the result_df
for sentiment, count in sentiment_count.items():
    percentage = count / len(cleaned_tw_list) * 100
    new_row = pd.DataFrame({'Sentiment': [sentiment], 'Total': [count], 'Percentage': [percentage]})
    result_df = pd.concat([result_df, new_row], ignore_index=True)
    
print(result_df)
# Out:
#   Sentiment Total  Percentage
# 0  positive   120   45.283019
# 1   neutral    98   36.981132
# 2  negative    47   17.735849

# %% [markdown]
# Create Pie Chart To Visualise Sentiments

# %%
#Creating PieChart

piechart = result_df

labels = ['Positive', 'Neutral','Negative']
sizes = result_df.Percentage
colors = ['green', 'yellow','red']

#Formatting labels with percentages
labels = ['Positive ['+str(round(sizes[0],2))+'%]' , 'Neutral ['+str(round(sizes[1],2))+'%]','Negative['+str(round(sizes[2],2))+'%]']

patches, texts = plt.pie(sizes,colors=colors, startangle=90)
plt.style.use('default')
plt.legend(patches, labels, loc="best")
plt.title("Sentiment Analysis Result" )
plt.axis('equal')
plt.show()

#This code will update the pie chart based on the values in the "sentiment" column of the cleaned_tw_list, and also display the percentages in the labels.

# %% [markdown]
# Create Table to House Query Result

# %%
# Connect to the database
connection = psycopg2.connect(
    host=db_host,
    port = db_port,
    user = db_user,
    password = db_password,
    database= db_name)

# Create a cursor object
cursor = connection.cursor()

# Define the table and columns
table_name = 'general_sentiments'
columns = ['tweet_id numeric', 'general_sentiment text']

# Create the table
cursor.execute(f"CREATE TABLE {table_name} ({', '.join(columns)})")

# Commit changes and close the connection
connection.commit()
connection.close()

# %% [markdown]
# Figuring Out General Sentiments From Calculating Sentiments Column in 'dim_sentiments'

# %%
# Connect to the database
connection = psycopg2.connect(
    host=db_host,
    port = db_port,
    user = db_user,
    password = db_password,
    database= db_name)
    
cursor = connection.cursor() 

# First query
'''query1 = """
SELECT 
    tweet_id, 
    COUNT(CASE WHEN sentiment = 'neutral' THEN 1 END) AS neutral_count, 
    COUNT(CASE WHEN sentiment = 'positive' THEN 1 END) AS positive_count, 
    COUNT(CASE WHEN sentiment = 'negative' THEN 1 END) AS negative_count
FROM  dim_sentiments
GROUP BY tweet_id
"""

cursor.execute(query1) 
result1 = cursor.fetchall() '''

# Second query
query2 = """
SELECT 
    tweet_id,
    COUNT(CASE WHEN sentiment = 'neutral' THEN 1 END) AS neutral_count, 
    COUNT(CASE WHEN sentiment = 'positive' THEN 1 END) AS positive_count, 
    COUNT(CASE WHEN sentiment = 'negative' THEN 1 END) AS negative_count,
    (COUNT(CASE WHEN sentiment = 'positive' THEN 1 END)*100.0 / COUNT(*)) AS positive_percent,
    (COUNT(CASE WHEN sentiment = 'neutral' THEN 1 END)*100.0 / COUNT(*)) AS neutral_percent,
    (COUNT(CASE WHEN sentiment = 'negative' THEN 1 END)*100.0 / COUNT(*)) AS negative_percent,
    CASE 
      WHEN (COUNT(CASE WHEN sentiment = 'positive' THEN 1 END)*100.0 / COUNT(*)) > 66 THEN 'strongly positive'
      WHEN (COUNT(CASE WHEN sentiment = 'positive' THEN 1 END)*100.0 / COUNT(*)) > 33 THEN 'positive'
      WHEN (COUNT(CASE WHEN sentiment = 'neutral' THEN 1 END)*100.0 / COUNT(*)) > 33 THEN 'neutral'
      WHEN (COUNT(CASE WHEN sentiment = 'negative' THEN 1 END)*100.0 / COUNT(*)) > 33 THEN 'negative'
      ELSE 'strongly negative'
    END AS general_sentiment
FROM dim_sentiments
GROUP BY tweet_id
"""

cursor.execute(query2)
result2 = cursor.fetchall()

connection.commit()

column_names = [desc[0] for desc in cursor.description]
general_sentiments = pd.DataFrame(result2, columns = column_names)
display(general_sentiments)
# Out:
#                tweet_id  neutral_count  positive_count  negative_count  \
# 0   1616533691156819968              5               8               0
# 1   1618371072486936578              5               3               2
# 2   1607416119496945665              4               3               5
# 3   1608324539779551232              5               3               1
# 4   1613995936585519104              6               9               0
# 5   1616524886201225217              6              10               1
# 6   1609109899233071104              5               7               1
# 7   1610374789759205380              3               4               3
# 8   1614761844010528770              6               2               6
# 9   1606396336592498688              4               4               2
# 10  1608663342956302337              5               5               0
# 11  1608175680407191552              4               4               3
# 12  1618826074724634625              3               7               2
# 13  1616531077790826497              3               8               4
# 14  1616853475220156417              6               7               2
# 15  1616590989145313283              4               7               6
# 16  1615398789585731587              5               9               4
# 17  1616179085507702785              4               9               4
# 18  1608922473839620096              6               7               1
# 19  1616594332907372544              9               4               0
#
#        positive_percent      neutral_percent     negative_percent  \
# 0   61.5384615384615385  38.4615384615384615                0E-20
# 1   30.0000000000000000  50.0000000000000000  20.0000000000000000
# 2   25.0000000000000000  33.3333333333333333  41.6666666666666667
# 3   33.3333333333333333  55.5555555555555556  11.1111111111111111
# 4   60.0000000000000000  40.0000000000000000                0E-20
# 5   58.8235294117647059  35.2941176470588235   5.8823529411764706
# 6   53.8461538461538462  38.4615384615384615   7.6923076923076923
# 7   40.0000000000000000  30.0000000000000000  30.0000000000000000
# 8   14.2857142857142857  42.8571428571428571  42.8571428571428571
# 9   40.0000000000000000  40.0000000000000000  20.0000000000000000
# 10  50.0000000000000000  50.0000000000000000                0E-20
# 11  36.3636363636363636  36.3636363636363636  27.2727272727272727
# 12  58.3333333333333333  25.0000000000000000  16.6666666666666667
# 13  53.3333333333333333  20.0000000000000000  26.6666666666666667
# 14  46.6666666666666667  40.0000000000000000  13.3333333333333333
# 15  41.1764705882352941  23.5294117647058824  35.2941176470588235
# 16  50.0000000000000000  27.7777777777777778  22.2222222222222222
# 17  52.9411764705882353  23.5294117647058824  23.5294117647058824
# 18  50.0000000000000000  42.8571428571428571   7.1428571428571429
# 19  30.7692307692307692  69.2307692307692308                0E-20
#
#    general_sentiment
# 0           positive
# 1            neutral
# 2            neutral
# 3           positive
# 4           positive
# 5           positive
# 6           positive
# 7           positive
# 8            neutral
# 9           positive
# 10          positive
# 11          positive
# 12          positive
# 13          positive
# 14          positive
# 15          positive
# 16          positive
# 17          positive
# 18          positive
# 19           neutral

# %%
cursor = connection.cursor()

for index, row in general_sentiments.iterrows():
    cursor.execute("INSERT INTO general_sentiments (tweet_id, general_sentiment) VALUES (%s, %s)", (row['tweet_id'], row['general_sentiment']))

#Commit Changes
connection.commit()

# %% [markdown]
# Close Connection

# %%
cursor.close()
connection.close()

# %% [markdown]
# Create Fact Table

# %%
# Connect to the database
connection = psycopg2.connect(
    host=db_host,
    port = db_port,
    user = db_user,
    password = db_password,
    database= db_name)

cursor = connection.cursor()

query = """
SELECT dtu.user_id, dtu.user_name, dtwk.tweet_id, dtwk.tweet, gs.general_sentiment, 'perception_id'
FROM dim_target_user AS dtu
INNER JOIN dim_tweets_w_keywords AS dtwk ON dtu.user_id = dtwk.user_id
INNER JOIN general_sentiments AS gs ON dtwk.tweet_id = gs.tweet_id
"""

cursor.execute(query)
result = cursor.fetchall()

connection.commit()

fact_public_perception = pd.DataFrame(result, columns = ['user_id', 'user_name', 'tweet_id', 'tweet', 'general_sentiment', 'perception_id'])
display(fact_public_perception)
# Out:
#      user_id user_name             tweet_id  \
# 0   44196397  elonmusk  1616533691156819968
# 1   44196397  elonmusk  1618371072486936578
# 2   44196397  elonmusk  1607416119496945665
# 3   44196397  elonmusk  1608324539779551232
# 4   44196397  elonmusk  1613995936585519104
# 5   44196397  elonmusk  1616524886201225217
# 6   44196397  elonmusk  1609109899233071104
# 7   44196397  elonmusk  1610374789759205380
# 8   44196397  elonmusk  1614761844010528770
# 9   44196397  elonmusk  1606396336592498688
# 10  44196397  elonmusk  1608663342956302337
# 11  44196397  elonmusk  1608175680407191552
# 12  44196397  elonmusk  1618826074724634625
# 13  44196397  elonmusk  1616531077790826497
# 14  44196397  elonmusk  1616853475220156417
# 15  44196397  elonmusk  1616590989145313283
# 16  44196397  elonmusk  1615398789585731587
# 17  44196397  elonmusk  1616179085507702785
# 18  44196397  elonmusk  1608922473839620096
# 19  44196397  elonmusk  1616594332907372544
#
#                                                 tweet general_sentiment  \
# 0   Major Twitter improvement we just released is ...          positive
# 1   Changed my name to Mr. Tweet, now Twitter won’...           neutral
# 2   Much more to The Twitter Files: Covid Editon t...           neutral
# 3   Significant backend server architecture change...          positive
# 4   Twitter will publish tweet recommendation code...          positive
# 5   Use pinned Lists to improve your Twitter exper...          positive
# 6   Twitter has a bookmark function accessible thr...          positive
# 7   Another episode of The Twitter Files https://t...          positive
# 8   Instagram makes people depressed &amp; Twitter...           neutral
# 9   Twitter votes for the right haha https://t.co/...          positive
# 10  New Twitter will strive to optimize unregrette...          positive
# 11  New Twitter policy is to follow the science, w...          positive
# 12                 Twitter is the PvP of social media          positive
# 13      Twitter app update now available on App Store          positive
# 14  Ads are too frequent on Twitter and too big. T...          positive
# 15  In coming months, Twitter will translate &amp;...          positive
# 16  Companies in general are missing the incredibl...          positive
# 17  Twitter is arguably already the least wrong so...          positive
# 18  New Twitter navigation coming in Jan that allo...          positive
# 19  Next Twitter update will remember whether you ...           neutral
#
#     perception_id
# 0   perception_id
# 1   perception_id
# 2   perception_id
# 3   perception_id
# 4   perception_id
# 5   perception_id
# 6   perception_id
# 7   perception_id
# 8   perception_id
# 9   perception_id
# 10  perception_id
# 11  perception_id
# 12  perception_id
# 13  perception_id
# 14  perception_id
# 15  perception_id
# 16  perception_id
# 17  perception_id
# 18  perception_id
# 19  perception_id

# %%
# Connect to the database
connection = psycopg2.connect(
    host=db_host,
    port = db_port,
    user = db_user,
    password = db_password,
    database= db_name)

cursor = connection.cursor()

query = """
CREATE TABLE fact_public_perception (
    perception_id SERIAL,
    user_id numeric,
    user_name text,
    tweet_id numeric,
    tweet text,
    general_sentiment text,
    PRIMARY KEY (perception_id),
    FOREIGN KEY (user_id) REFERENCES dim_target_user(user_id),
    FOREIGN KEY (tweet_id) REFERENCES dim_tweets_w_keywords(tweet_id)
);
"""

cursor.execute(query)
connection.commit()

# %% [markdown]
# Commit Query and Populate Fact Table

# %%
cursor = connection.cursor()

for index, row in fact_public_perception.iterrows():
    cursor.execute("INSERT INTO fact_public_perception (user_id,  user_name, tweet_id, tweet, general_sentiment) VALUES (%s, %s, %s, %s, %s)", (row['user_id'], row['user_name'], row['tweet_id'], row['tweet'], row['general_sentiment']))

#Commit Changes
connection.commit()

# %% [markdown]
# Close Connection

# %%
cursor.close()
connection.close()

# %% [markdown]
# ## The findings:
#
# 1)	Yes, there is a **positive correlation** between the number of ‘Likes’ and the number of ‘Retweets’ as can be seen from the Scatterplot.
#
# 2)	By analyzing using Vader, the sentiments towards Elon Musk are **generally positive** at 44.6%, with 34.5% neutral and 20.8% negative. However, due to the **limitation** with Vader being not able to detect sarcasm, this numbers will likely not be accurate, taking the following tweet as an example:
#
# <div>
# <img src="images/limitation.png" width="600" border=1px align="center"/>
# </div>

# %% [markdown]
# **End of Project - Thank You!**
